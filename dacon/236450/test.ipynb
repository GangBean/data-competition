# %%
import pandas as pd
from src.features.features import create_feature

# %%
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# %%
create_feature(train_df=train_df, test_df=test_df)

# %%
train_df = train_df.drop(columns=train_df.select_dtypes(include=['object']).columns, axis=1)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   연간 소득              10000 non-null  float64
#  1   체납 세금 압류 횟수        10000 non-null  float64
#  2   개설된 신용계좌 수         10000 non-null  int64
#  3   신용 거래 연수           10000 non-null  float64
#  4   최대 신용한도            10000 non-null  float64
#  5   신용 문제 발생 횟수        10000 non-null  int64
#  6   마지막 연체 이후 경과 개월 수  10000 non-null  int64
#  7   개인 파산 횟수           10000 non-null  int64
#  8   현재 대출 잔액           10000 non-null  float64
#  9   현재 미상환 신용액         10000 non-null  float64
#  10  월 상환 부채액           10000 non-null  float64
#  11  신용 점수              10000 non-null  int64
#  12  채무 불이행 여부          10000 non-null  int64
#  13  자산                 10000 non-null  float64
#  14  대출 이자율             10000 non-null  float64
#  15  대출 비율              10000 non-null  float64
#  16  신용 비율              10000 non-null  float64
#  17  주거 형태 채무 불이행률      10000 non-null  float64
#  18  대출 목적 채무 불이행률      10000 non-null  float64
#  19  대출 상환 기간 채무 불이행률   10000 non-null  float64
#  20  대출 목적_고위험          10000 non-null  int64
#  21  근속 연수              10000 non-null  int64
#  22  장기 근속 여부           10000 non-null  int64
#  23  최근 연체 있음           10000 non-null  int64
#  24  DTI                10000 non-null  float64
#  25  LTV                10000 non-null  float64
#  26  로그 신용 점수           10000 non-null  float64
#  27  신용 문제율             10000 non-null  float64
#  28  파산 경험 여부           10000 non-null  int64
#  29  부채 대비 신용 점수        10000 non-null  float64
#  30  총 부채 비율            10000 non-null  float64
#  31  월 소득 대비 부채 비율      10000 non-null  float64
#  32  신용-부채 변화율          10000 non-null  float64
#  33  근속 연수 대비 소득        10000 non-null  float64
#  34  연체 발생 빈도           10000 non-null  float64
#  35  최근 연체 위험 지표        10000 non-null  float64
#  36  금융 위험 지수           10000 non-null  float64
#  37  상환 속도              10000 non-null  float64
#  38  자산 부족 정도           10000 non-null  float64
#  39  재정 스트레스 지표         10000 non-null  float64
#  40  단기 부채 위험           10000 non-null  float64
#  41  주거 형태_소득           10000 non-null  float64
#  42  과거 신용 위험 지표        10000 non-null  float64
#  43  잔액 대비 상환 속도        10000 non-null  float64
#  44  부채 증가 위험           10000 non-null  float64
#  45  대출 목적_부채 부담        10000 non-null  float64
#  46  신용 위험              10000 non-null  float64
# dtypes: float64(36), int64(11)
# memory usage: 3.6 MB

# %%
from sklearn.neighbors import NearestNeighbors

# Feature 간 거리 계산
X = train_df.values.T  # Feature별 값들을 행렬로 변환
nbrs = NearestNeighbors(n_neighbors=5, metric='euclidean').fit(X)
distances, indices = nbrs.kneighbors(X)

# 유사한 feature 그룹 확인
similar_features = {train_df.columns[i]: [train_df.columns[j] for j in indices[i]] for i in range(len(train_df.columns))}
print(similar_features)
# Out:
# {'연간 소득': ['연간 소득', '자산', '주거 형태_소득', '최대 신용한도', '현재 대출 잔액'], '체납 세금 압류 횟수': ['체납 세금 압류 횟수', '과거 신용 위험 지표', '신용 문제율', '연체 발생 빈도', 'LTV'], '개설된 신용계좌 수': ['개설된 신용계좌 수', '로그 신용 점수', '근속 연수', '대출 이자율', '신용 거래 연수'], '신용 거래 연수': ['신용 거래 연수', '개설된 신용계좌 수', '로그 신용 점수', '근속 연수', '금융 위험 지수'], '최대 신용한도': ['최대 신용한도', '주거 형태_소득', '현재 대출 잔액', '현재 미상환 신용액', '근속 연수 대비 소득'], '신용 문제 발생 횟수': ['신용 문제 발생 횟수', '개인 파산 횟수', '체납 세금 압류 횟수', '파산 경험 여부', '주거 형태 채무 불이행률'], '마지막 연체 이후 경과 개월 수': ['마지막 연체 이후 경과 개월 수', '최근 연체 위험 지표', '신용 거래 연수', '개설된 신용계좌 수', '금융 위험 지수'], '개인 파산 횟수': ['개인 파산 횟수', '파산 경험 여부', '과거 신용 위험 지표', '주거 형태 채무 불이행률', '대출 목적 채무 불이행률'], '현재 대출 잔액': ['현재 대출 잔액', '현재 미상환 신용액', '잔액 대비 상환 속도', '주거 형태_소득', '월 상환 부채액'], '현재 미상환 신용액': ['현재 미상환 신용액', '현재 대출 잔액', '잔액 대비 상환 속도', '월 상환 부채액', '대출 목적_부채 부담'], '월 상환 부채액': ['월 상환 부채액', '대출 목적_부채 부담', '단기 부채 위험', '신용 점수', '부채 대비 신용 점수'], '신용 점수': ['신용 점수', '마지막 연체 이후 경과 개월 수', '부채 대비 신용 점수', '최근 연체 위험 지표', '신용 거래 연수'], '채무 불이행 여부': ['채무 불이행 여부', '대출 목적 채무 불이행률', '대출 상환 기간 채무 불이행률', '주거 형태 채무 불이행률', '총 부채 비율'], '자산': ['자산', '연간 소득', '주거 형태_소득', '최대 신용한도', '현재 대출 잔액'], '대출 이자율': ['대출 이자율', '로그 신용 점수', '근속 연수', '대출 비율', '자산 부족 정도'], '대출 비율': ['대출 비율', '대출 목적_고위험', '자산 부족 정도', '장기 근속 여부', '총 부채 비율'], '신용 비율': ['신용 비율', '신용-부채 변화율', '금융 위험 지수', '개설된 신용계좌 수', '로그 신용 점수'], '주거 형태 채무 불이행률': ['주거 형태 채무 불이행률', '대출 상환 기간 채무 불이행률', '대출 목적 채무 불이행률', 'LTV', '총 부채 비율'], '대출 목적 채무 불이행률': ['대출 목적 채무 불이행률', '주거 형태 채무 불이행률', '대출 상환 기간 채무 불이행률', '총 부채 비율', 'LTV'], '대출 상환 기간 채무 불이행률': ['대출 상환 기간 채무 불이행률', '주거 형태 채무 불이행률', '대출 목적 채무 불이행률', 'LTV', '총 부채 비율'], '대출 목적_고위험': ['대출 목적_고위험', '대출 목적 채무 불이행률', '자산 부족 정도', '주거 형태 채무 불이행률', '총 부채 비율'], '근속 연수': ['근속 연수', '로그 신용 점수', '대출 이자율', '자산 부족 정도', '장기 근속 여부'], '장기 근속 여부': ['장기 근속 여부', '주거 형태 채무 불이행률', '대출 상환 기간 채무 불이행률', '대출 목적 채무 불이행률', '총 부채 비율'], '최근 연체 있음': ['최근 연체 있음', 'DTI', '상환 속도', '신용 위험', '재정 스트레스 지표'], 'DTI': ['DTI', '상환 속도', '재정 스트레스 지표', '신용 위험', '부채 증가 위험'], 'LTV': ['LTV', '월 소득 대비 부채 비율', '대출 상환 기간 채무 불이행률', '주거 형태 채무 불이행률', '대출 목적 채무 불이행률'], '로그 신용 점수': ['로그 신용 점수', '근속 연수', '대출 이자율', '자산 부족 정도', '대출 비율'], '신용 문제율': ['신용 문제율', '연체 발생 빈도', '과거 신용 위험 지표', 'DTI', '상환 속도'], '파산 경험 여부': ['파산 경험 여부', '과거 신용 위험 지표', 'LTV', '연체 발생 빈도', '신용 문제율'], '부채 대비 신용 점수': ['부채 대비 신용 점수', '신용 거래 연수', '금융 위험 지수', '개설된 신용계좌 수', '신용 비율'], '총 부채 비율': ['총 부채 비율', '주거 형태 채무 불이행률', '대출 상환 기간 채무 불이행률', '대출 목적 채무 불이행률', 'LTV'], '월 소득 대비 부채 비율': ['월 소득 대비 부채 비율', 'LTV', 'DTI', '상환 속도', '신용 문제율'], '신용-부채 변화율': ['신용-부채 변화율', '신용 비율', '금융 위험 지수', '개설된 신용계좌 수', '로그 신용 점수'], '근속 연수 대비 소득': ['근속 연수 대비 소득', '현재 대출 잔액', '주거 형태_소득', '현재 미상환 신용액', '잔액 대비 상환 속도'], '연체 발생 빈도': ['신용 문제율', '연체 발생 빈도', '과거 신용 위험 지표', 'DTI', '상환 속도'], '최근 연체 위험 지표': ['최근 연체 위험 지표', '마지막 연체 이후 경과 개월 수', '신용 거래 연수', '개설된 신용계좌 수', '금융 위험 지수'], '금융 위험 지수': ['금융 위험 지수', '신용 비율', '신용-부채 변화율', '개설된 신용계좌 수', '신용 거래 연수'], '상환 속도': ['상환 속도', 'DTI', '재정 스트레스 지표', '신용 위험', '부채 증가 위험'], '자산 부족 정도': ['자산 부족 정도', '대출 목적_고위험', '대출 비율', '장기 근속 여부', '총 부채 비율'], '재정 스트레스 지표': ['재정 스트레스 지표', '부채 증가 위험', '신용 위험', '상환 속도', 'DTI'], '단기 부채 위험': ['단기 부채 위험', '신용 점수', '부채 대비 신용 점수', '신용 거래 연수', '금융 위험 지수'], '주거 형태_소득': ['주거 형태_소득', '현재 대출 잔액', '현재 미상환 신용액', '근속 연수 대비 소득', '잔액 대비 상환 속도'], '과거 신용 위험 지표': ['과거 신용 위험 지표', '신용 문제율', '연체 발생 빈도', 'DTI', '상환 속도'], '잔액 대비 상환 속도': ['잔액 대비 상환 속도', '월 상환 부채액', '대출 목적_부채 부담', '단기 부채 위험', '신용 점수'], '부채 증가 위험': ['부채 증가 위험', '재정 스트레스 지표', '신용 위험', '상환 속도', 'DTI'], '대출 목적_부채 부담': ['대출 목적_부채 부담', '신용 점수', '부채 대비 신용 점수', '마지막 연체 이후 경과 개월 수', '최근 연체 위험 지표'], '신용 위험': ['신용 위험', '재정 스트레스 지표', '부채 증가 위험', '상환 속도', 'DTI']}

# %%
similar_features
# Out:
# {'연간 소득': ['연간 소득', '자산', '주거 형태_소득', '최대 신용한도', '현재 대출 잔액'],
#  '체납 세금 압류 횟수': ['체납 세금 압류 횟수', '과거 신용 위험 지표', '신용 문제율', '연체 발생 빈도', 'LTV'],
#  '개설된 신용계좌 수': ['개설된 신용계좌 수', '로그 신용 점수', '근속 연수', '대출 이자율', '신용 거래 연수'],
#  '신용 거래 연수': ['신용 거래 연수', '개설된 신용계좌 수', '로그 신용 점수', '근속 연수', '금융 위험 지수'],
#  '최대 신용한도': ['최대 신용한도', '주거 형태_소득', '현재 대출 잔액', '현재 미상환 신용액', '근속 연수 대비 소득'],
#  '신용 문제 발생 횟수': ['신용 문제 발생 횟수',
#   '개인 파산 횟수',
#   '체납 세금 압류 횟수',
#   '파산 경험 여부',
#   '주거 형태 채무 불이행률'],
#  '마지막 연체 이후 경과 개월 수': ['마지막 연체 이후 경과 개월 수',
#   '최근 연체 위험 지표',
#   '신용 거래 연수',
#   '개설된 신용계좌 수',
#   '금융 위험 지수'],
#  '개인 파산 횟수': ['개인 파산 횟수',
#   '파산 경험 여부',
#   '과거 신용 위험 지표',
#   '주거 형태 채무 불이행률',
#   '대출 목적 채무 불이행률'],
#  '현재 대출 잔액': ['현재 대출 잔액', '현재 미상환 신용액', '잔액 대비 상환 속도', '주거 형태_소득', '월 상환 부채액'],
#  '현재 미상환 신용액': ['현재 미상환 신용액',
#   '현재 대출 잔액',
#   '잔액 대비 상환 속도',
#   '월 상환 부채액',
#   '대출 목적_부채 부담'],
#  '월 상환 부채액': ['월 상환 부채액', '대출 목적_부채 부담', '단기 부채 위험', '신용 점수', '부채 대비 신용 점수'],
#  '신용 점수': ['신용 점수',
#   '마지막 연체 이후 경과 개월 수',
#   '부채 대비 신용 점수',
#   '최근 연체 위험 지표',
#   '신용 거래 연수'],
#  '채무 불이행 여부': ['채무 불이행 여부',
#   '대출 목적 채무 불이행률',
#   '대출 상환 기간 채무 불이행률',
#   '주거 형태 채무 불이행률',
#   '총 부채 비율'],
#  '자산': ['자산', '연간 소득', '주거 형태_소득', '최대 신용한도', '현재 대출 잔액'],
#  '대출 이자율': ['대출 이자율', '로그 신용 점수', '근속 연수', '대출 비율', '자산 부족 정도'],
#  '대출 비율': ['대출 비율', '대출 목적_고위험', '자산 부족 정도', '장기 근속 여부', '총 부채 비율'],
#  '신용 비율': ['신용 비율', '신용-부채 변화율', '금융 위험 지수', '개설된 신용계좌 수', '로그 신용 점수'],
#  '주거 형태 채무 불이행률': ['주거 형태 채무 불이행률',
#   '대출 상환 기간 채무 불이행률',
#   '대출 목적 채무 불이행률',
#   'LTV',
#   '총 부채 비율'],
#  '대출 목적 채무 불이행률': ['대출 목적 채무 불이행률',
#   '주거 형태 채무 불이행률',
#   '대출 상환 기간 채무 불이행률',
#   '총 부채 비율',
#   'LTV'],
#  '대출 상환 기간 채무 불이행률': ['대출 상환 기간 채무 불이행률',
#   '주거 형태 채무 불이행률',
#   '대출 목적 채무 불이행률',
#   'LTV',
#   '총 부채 비율'],
#  '대출 목적_고위험': ['대출 목적_고위험',
#   '대출 목적 채무 불이행률',
#   '자산 부족 정도',
#   '주거 형태 채무 불이행률',
#   '총 부채 비율'],
#  '근속 연수': ['근속 연수', '로그 신용 점수', '대출 이자율', '자산 부족 정도', '장기 근속 여부'],
#  '장기 근속 여부': ['장기 근속 여부',
#   '주거 형태 채무 불이행률',
#   '대출 상환 기간 채무 불이행률',
#   '대출 목적 채무 불이행률',
#   '총 부채 비율'],
#  '최근 연체 있음': ['최근 연체 있음', 'DTI', '상환 속도', '신용 위험', '재정 스트레스 지표'],
#  'DTI': ['DTI', '상환 속도', '재정 스트레스 지표', '신용 위험', '부채 증가 위험'],
#  'LTV': ['LTV',
#   '월 소득 대비 부채 비율',
#   '대출 상환 기간 채무 불이행률',
#   '주거 형태 채무 불이행률',
#   '대출 목적 채무 불이행률'],
#  '로그 신용 점수': ['로그 신용 점수', '근속 연수', '대출 이자율', '자산 부족 정도', '대출 비율'],
#  '신용 문제율': ['신용 문제율', '연체 발생 빈도', '과거 신용 위험 지표', 'DTI', '상환 속도'],
#  '파산 경험 여부': ['파산 경험 여부', '과거 신용 위험 지표', 'LTV', '연체 발생 빈도', '신용 문제율'],
#  '부채 대비 신용 점수': ['부채 대비 신용 점수', '신용 거래 연수', '금융 위험 지수', '개설된 신용계좌 수', '신용 비율'],
#  '총 부채 비율': ['총 부채 비율',
#   '주거 형태 채무 불이행률',
#   '대출 상환 기간 채무 불이행률',
#   '대출 목적 채무 불이행률',
#   'LTV'],
#  '월 소득 대비 부채 비율': ['월 소득 대비 부채 비율', 'LTV', 'DTI', '상환 속도', '신용 문제율'],
#  '신용-부채 변화율': ['신용-부채 변화율', '신용 비율', '금융 위험 지수', '개설된 신용계좌 수', '로그 신용 점수'],
#  '근속 연수 대비 소득': ['근속 연수 대비 소득',
#   '현재 대출 잔액',
#   '주거 형태_소득',
#   '현재 미상환 신용액',
#   '잔액 대비 상환 속도'],
#  '연체 발생 빈도': ['신용 문제율', '연체 발생 빈도', '과거 신용 위험 지표', 'DTI', '상환 속도'],
#  '최근 연체 위험 지표': ['최근 연체 위험 지표',
#   '마지막 연체 이후 경과 개월 수',
#   '신용 거래 연수',
#   '개설된 신용계좌 수',
#   '금융 위험 지수'],
#  '금융 위험 지수': ['금융 위험 지수', '신용 비율', '신용-부채 변화율', '개설된 신용계좌 수', '신용 거래 연수'],
#  '상환 속도': ['상환 속도', 'DTI', '재정 스트레스 지표', '신용 위험', '부채 증가 위험'],
#  '자산 부족 정도': ['자산 부족 정도', '대출 목적_고위험', '대출 비율', '장기 근속 여부', '총 부채 비율'],
#  '재정 스트레스 지표': ['재정 스트레스 지표', '부채 증가 위험', '신용 위험', '상환 속도', 'DTI'],
#  '단기 부채 위험': ['단기 부채 위험', '신용 점수', '부채 대비 신용 점수', '신용 거래 연수', '금융 위험 지수'],
#  '주거 형태_소득': ['주거 형태_소득',
#   '현재 대출 잔액',
#   '현재 미상환 신용액',
#   '근속 연수 대비 소득',
#   '잔액 대비 상환 속도'],
#  '과거 신용 위험 지표': ['과거 신용 위험 지표', '신용 문제율', '연체 발생 빈도', 'DTI', '상환 속도'],
#  '잔액 대비 상환 속도': ['잔액 대비 상환 속도',
#   '월 상환 부채액',
#   '대출 목적_부채 부담',
#   '단기 부채 위험',
#   '신용 점수'],
#  '부채 증가 위험': ['부채 증가 위험', '재정 스트레스 지표', '신용 위험', '상환 속도', 'DTI'],
#  '대출 목적_부채 부담': ['대출 목적_부채 부담',
#   '신용 점수',
#   '부채 대비 신용 점수',
#   '마지막 연체 이후 경과 개월 수',
#   '최근 연체 위험 지표'],
#  '신용 위험': ['신용 위험', '재정 스트레스 지표', '부채 증가 위험', '상환 속도', 'DTI']}
