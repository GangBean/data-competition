# %%
import sqlite3
import sys
import os
import pandas as pd

# 현재 노트북의 디렉터리를 기준으로 루트 디렉터리 경로를 추가
project_root = os.path.abspath(os.path.join(os.path.dirname(os.path.abspath('')), ''))
print(project_root)
sys.path.append(project_root)
# Out:
# /Users/jsh/Projects/dacon/ic50-prediction

# %% [markdown]
# ## Reference
# - https://medium.com/standigm/rdkit%EC%9D%84-%ED%99%9C%EC%9A%A9%ED%95%9C-chembl-%EB%B6%84%EC%9E%90%EB%93%A4-%EC%82%AC%EC%9D%B4%EC%9D%98-%EC%9C%A0%EC%82%AC%EB%8F%84-%EA%B2%80%EC%83%89-60307ccdb441

# %%
DATABASE_URL = "../data/chembl_34/chembl_34_sqlite/chembl_34.db"
db = sqlite3.connect(DATABASE_URL)

# %%
table_count = [
    (table, count) for table, in db.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()
        for count, in db.execute(f"SELECT count(*) FROM {table}").fetchall()
]

table_count_df = pd.DataFrame(table_count, columns=['table', 'count']).sort_values(by='count', ascending=False).reset_index(drop=True)

# %%
table_count_df
# Out:
#                          table     count
# 0                   activities  20772701
# 1          activity_properties  10314826
# 2             chembl_id_lookup   4640251
# 3   compound_structural_alerts   4436020
# 4             compound_records   3106257
# ..                         ...       ...
# 75                  assay_type         6
# 76           relationship_type         6
# 77       structural_alert_sets         5
# 78             curation_lookup         3
# 79           component_domains         0
#
# [80 rows x 2 columns]

# %%
train_df = pd.read_csv('../data/train.csv')
test_df = pd.read_csv('../data/test.csv')

# %%
molecule_ids = train_df['Molecule ChEMBL ID'].unique()
molecule_ids_str = ', '.join([f"'{molecule_id}'" for molecule_id in molecule_ids])
print(molecule_ids.shape)

# SQL 쿼리 실행
db.execute(f"SELECT count(*) FROM molecule_dictionary WHERE chembl_id IN ({molecule_ids_str})").fetchall()
# Out:
# (1952,)
# [(1952,)]

# %%
document_ids = train_df['Document ChEMBL ID'].unique()
document_ids_str = ', '.join([f"'{document_id}'" for document_id in document_ids])
print(document_ids.shape)

db.execute(f"select count(*) from docs where chembl_id in ({document_ids_str})").fetchall()
# Out:
# (66,)
# [(66,)]

# %%
db.execute("select name from sqlite_master where type='table' and name like '%doc%'").fetchall()
# Out:
# [('docs',)]

# %%
document_ids = train_df['Document ChEMBL ID'].unique()
document_ids_str = ', '.join([f"'{document_id}'" for document_id in document_ids])
print(document_ids.shape)

db.execute(f"select count(*) from docs where chembl_id in ({document_ids_str})").fetchall()
# Out:
# (66,)
# [(66,)]

# %%
db.execute("select name from sqlite_master where type='table' and name like '%assay%'").fetchall()
# Out:
# [('assay_type',),
#  ('bioassay_ontology',),
#  ('assay_classification',),
#  ('assays',),
#  ('assay_class_map',),
#  ('assay_parameters',)]

# %%
document_ids = train_df['Assay ChEMBL ID'].unique()
document_ids_str = ', '.join([f"'{document_id}'" for document_id in document_ids])
print(document_ids.shape)

db.execute(f"select count(*) from assays where chembl_id in ({document_ids_str})").fetchall()
# Out:
# (72,)
# [(72,)]

# %%
db.execute("select name, type from sqlite_master group by name, type").fetchall()
# Out:
# [('action_type', 'table'),
#  ('activities', 'table'),
#  ('activity_properties', 'table'),
#  ('activity_smid', 'table'),
#  ('activity_stds_lookup', 'table'),
#  ('activity_supp', 'table'),
#  ('activity_supp_map', 'table'),
#  ('assay_class_map', 'table'),
#  ('assay_classification', 'table'),
#  ('assay_classification_pk', 'index'),
#  ('assay_parameters', 'table'),
#  ('assay_type', 'table'),
#  ('assays', 'table'),
#  ('atc_classification', 'table'),
#  ('binding_sites', 'table'),
#  ('bio_component_seqs_pk', 'index'),
#  ('bio_component_sequences', 'table'),
#  ('bioassay_ontology', 'table'),
#  ('biotherapeutic_components', 'table'),
#  ('biotherapeutics', 'table'),
#  ('bmx_doc_iss', 'index'),
#  ('bmx_doc_jrnl', 'index'),
#  ('bmx_doc_vol', 'index'),
#  ('bmx_doc_year', 'index'),
#  ('cell_dictionary', 'table'),
#  ('chembl_id_lookup', 'table'),
#  ('chembl_release', 'table'),
#  ('component_class', 'table'),
#  ('component_domains', 'table'),
#  ('component_go', 'table'),
#  ('component_sequences', 'table'),
#  ('component_synonyms', 'table'),
#  ('compound_properties', 'table'),
#  ('compound_records', 'table'),
#  ('compound_structural_alerts', 'table'),
#  ('compound_structures', 'table'),
#  ('compound_structures_pk', 'index'),
#  ('confidence_score_lookup', 'table'),
#  ('curation_lookup', 'table'),
#  ('data_validity_lookup', 'table'),
#  ('defined_daily_dose', 'table'),
#  ('docs', 'table'),
#  ('domains', 'table'),
#  ('drug_indication', 'table'),
#  ('drug_indication_pk', 'index'),
#  ('drug_mechanism', 'table'),
#  ('drug_warning', 'table'),
#  ('fk_act_assay_id', 'index'),
#  ('fk_act_doc_id', 'index'),
#  ('fk_act_molregno', 'index'),
#  ('fk_act_record_id', 'index'),
#  ('fk_comp_rec_docid', 'index'),
#  ('fk_comp_rec_molregno', 'index'),
#  ('formulations', 'table'),
#  ('frac_classification', 'table'),
#  ('go_classification', 'table'),
#  ('hrac_classification', 'table'),
#  ('idx_acc_relation', 'index'),
#  ('idx_act_pchembl', 'index'),
#  ('idx_act_prop_text', 'index'),
#  ('idx_act_rel', 'index'),
#  ('idx_act_src_id', 'index'),
#  ('idx_act_std_text', 'index'),
#  ('idx_act_std_type', 'index'),
#  ('idx_act_std_unit', 'index'),
#  ('idx_act_std_upper', 'index'),
#  ('idx_act_std_val', 'index'),
#  ('idx_act_text', 'index'),
#  ('idx_act_type', 'index'),
#  ('idx_act_units', 'index'),
#  ('idx_act_upper', 'index'),
#  ('idx_act_val', 'index'),
#  ('idx_actprop_relation', 'index'),
#  ('idx_actprop_resflag', 'index'),
#  ('idx_actprop_type', 'index'),
#  ('idx_actprop_units', 'index'),
#  ('idx_actprop_val', 'index'),
#  ('idx_actsupp_rel', 'index'),
#  ('idx_actsupp_std_rel', 'index'),
#  ('idx_actsupp_std_text', 'index'),
#  ('idx_actsupp_std_type', 'index'),
#  ('idx_actsupp_std_units', 'index'),
#  ('idx_actsupp_std_val', 'index'),
#  ('idx_actsupp_text', 'index'),
#  ('idx_actsupp_type', 'index'),
#  ('idx_actsupp_units', 'index'),
#  ('idx_actsupp_val', 'index'),
#  ('idx_assay_assay_id', 'index'),
#  ('idx_assay_param_rel', 'index'),
#  ('idx_assay_param_std_rel', 'index'),
#  ('idx_assay_param_std_text', 'index'),
#  ('idx_assay_param_std_type', 'index'),
#  ('idx_assay_param_std_units', 'index'),
#  ('idx_assay_param_std_val', 'index'),
#  ('idx_assay_param_text', 'index'),
#  ('idx_assay_param_type', 'index'),
#  ('idx_assay_param_units', 'index'),
#  ('idx_assay_param_val', 'index'),
#  ('idx_assays_chembl_id', 'index'),
#  ('idx_assays_desc', 'index'),
#  ('idx_assays_doc_id', 'index'),
#  ('idx_assays_src_id', 'index'),
#  ('idx_cmpdstr_smiles', 'index'),
#  ('idx_cmpdstr_stdinchi', 'index'),
#  ('idx_cmpdstr_stdkey', 'index'),
#  ('idx_comp_rec_cidx', 'index'),
#  ('idx_comp_rec_ckey', 'index'),
#  ('idx_comp_rec_srccpid', 'index'),
#  ('idx_comp_rec_srcid', 'index'),
#  ('idx_cp_alogp', 'index'),
#  ('idx_cp_hba', 'index'),
#  ('idx_cp_hbd', 'index'),
#  ('idx_cp_mw', 'index'),
#  ('idx_cp_psa', 'index'),
#  ('idx_cp_ro5', 'index'),
#  ('idx_cp_rtb', 'index'),
#  ('idx_docs_pmid', 'index'),
#  ('idx_moldict_chembl_id', 'index'),
#  ('idx_moldict_max_phase', 'index'),
#  ('idx_moldict_pref_name', 'index'),
#  ('idx_moldict_ther_flag', 'index'),
#  ('idx_molhier_parent', 'index'),
#  ('idx_td_chembl_id', 'index'),
#  ('idx_td_org', 'index'),
#  ('idx_td_pname', 'index'),
#  ('idx_td_t_type', 'index'),
#  ('idx_td_taxid', 'index'),
#  ('indication_refs', 'table'),
#  ('irac_classification', 'table'),
#  ('ligand_eff', 'table'),
#  ('mechanism_refs', 'table'),
#  ('mechanism_refs_pk', 'index'),
#  ('mechanism_refs_uk', 'index'),
#  ('metabolism', 'table'),
#  ('metabolism_refs', 'table'),
#  ('molecule_atc_classification', 'table'),
#  ('molecule_dictionary', 'table'),
#  ('molecule_frac_classification', 'table'),
#  ('molecule_hierarchy', 'table'),
#  ('molecule_hrac_classification', 'table'),
#  ('molecule_irac_classification', 'table'),
#  ('molecule_synonyms', 'table'),
#  ('organism_class', 'table'),
#  ('organism_class_pk', 'index'),
#  ('patent_use_codes', 'table'),
#  ('pk_actsmid', 'index'),
#  ('pk_com_molreg', 'index'),
#  ('pk_comp_rec_recid', 'index'),
#  ('pk_doc_doc_id', 'index'),
#  ('pk_rt_rt', 'index'),
#  ('pk_tt_tt', 'index'),
#  ('predicted_binding_domains', 'table'),
#  ('product_patents', 'table'),
#  ('products', 'table'),
#  ('protclass_pk', 'index'),
#  ('protein_class_synonyms', 'table'),
#  ('protein_classification', 'table'),
#  ('relationship_type', 'table'),
#  ('research_companies', 'table'),
#  ('research_stem', 'table'),
#  ('site_components', 'table'),
#  ('source', 'table'),
#  ('sqlite_autoindex_action_type_1', 'index'),
#  ('sqlite_autoindex_activities_1', 'index'),
#  ('sqlite_autoindex_activity_properties_1', 'index'),
#  ('sqlite_autoindex_activity_properties_2', 'index'),
#  ('sqlite_autoindex_activity_smid_1', 'index'),
#  ('sqlite_autoindex_activity_stds_lookup_1', 'index'),
#  ('sqlite_autoindex_activity_stds_lookup_2', 'index'),
#  ('sqlite_autoindex_activity_supp_1', 'index'),
#  ('sqlite_autoindex_activity_supp_2', 'index'),
#  ('sqlite_autoindex_activity_supp_map_1', 'index'),
#  ('sqlite_autoindex_assay_class_map_1', 'index'),
#  ('sqlite_autoindex_assay_class_map_2', 'index'),
#  ('sqlite_autoindex_assay_classification_1', 'index'),
#  ('sqlite_autoindex_assay_classification_2', 'index'),
#  ('sqlite_autoindex_assay_parameters_1', 'index'),
#  ('sqlite_autoindex_assay_parameters_2', 'index'),
#  ('sqlite_autoindex_assay_type_1', 'index'),
#  ('sqlite_autoindex_assays_1', 'index'),
#  ('sqlite_autoindex_assays_2', 'index'),
#  ('sqlite_autoindex_atc_classification_1', 'index'),
#  ('sqlite_autoindex_binding_sites_1', 'index'),
#  ('sqlite_autoindex_bio_component_sequences_1', 'index'),
#  ('sqlite_autoindex_bioassay_ontology_1', 'index'),
#  ('sqlite_autoindex_biotherapeutic_components_1', 'index'),
#  ('sqlite_autoindex_biotherapeutic_components_2', 'index'),
#  ('sqlite_autoindex_biotherapeutics_1', 'index'),
#  ('sqlite_autoindex_cell_dictionary_1', 'index'),
#  ('sqlite_autoindex_cell_dictionary_2', 'index'),
#  ('sqlite_autoindex_cell_dictionary_3', 'index'),
#  ('sqlite_autoindex_chembl_id_lookup_1', 'index'),
#  ('sqlite_autoindex_chembl_id_lookup_2', 'index'),
#  ('sqlite_autoindex_component_class_1', 'index'),
#  ('sqlite_autoindex_component_class_2', 'index'),
#  ('sqlite_autoindex_component_domains_1', 'index'),
#  ('sqlite_autoindex_component_domains_2', 'index'),
#  ('sqlite_autoindex_component_go_1', 'index'),
#  ('sqlite_autoindex_component_go_2', 'index'),
#  ('sqlite_autoindex_component_sequences_1', 'index'),
#  ('sqlite_autoindex_component_sequences_2', 'index'),
#  ('sqlite_autoindex_component_synonyms_1', 'index'),
#  ('sqlite_autoindex_component_synonyms_2', 'index'),
#  ('sqlite_autoindex_compound_properties_1', 'index'),
#  ('sqlite_autoindex_compound_records_1', 'index'),
#  ('sqlite_autoindex_compound_structural_alerts_1', 'index'),
#  ('sqlite_autoindex_compound_structural_alerts_2', 'index'),
#  ('sqlite_autoindex_compound_structures_1', 'index'),
#  ('sqlite_autoindex_compound_structures_2', 'index'),
#  ('sqlite_autoindex_compound_structures_3', 'index'),
#  ('sqlite_autoindex_confidence_score_lookup_1', 'index'),
#  ('sqlite_autoindex_curation_lookup_1', 'index'),
#  ('sqlite_autoindex_data_validity_lookup_1', 'index'),
#  ('sqlite_autoindex_defined_daily_dose_1', 'index'),
#  ('sqlite_autoindex_docs_1', 'index'),
#  ('sqlite_autoindex_docs_2', 'index'),
#  ('sqlite_autoindex_domains_1', 'index'),
#  ('sqlite_autoindex_drug_indication_1', 'index'),
#  ('sqlite_autoindex_drug_indication_2', 'index'),
#  ('sqlite_autoindex_drug_mechanism_1', 'index'),
#  ('sqlite_autoindex_drug_warning_1', 'index'),
#  ('sqlite_autoindex_formulations_1', 'index'),
#  ('sqlite_autoindex_formulations_2', 'index'),
#  ('sqlite_autoindex_frac_classification_1', 'index'),
#  ('sqlite_autoindex_frac_classification_2', 'index'),
#  ('sqlite_autoindex_go_classification_1', 'index'),
#  ('sqlite_autoindex_hrac_classification_1', 'index'),
#  ('sqlite_autoindex_hrac_classification_2', 'index'),
#  ('sqlite_autoindex_indication_refs_1', 'index'),
#  ('sqlite_autoindex_indication_refs_2', 'index'),
#  ('sqlite_autoindex_irac_classification_1', 'index'),
#  ('sqlite_autoindex_irac_classification_2', 'index'),
#  ('sqlite_autoindex_ligand_eff_1', 'index'),
#  ('sqlite_autoindex_mechanism_refs_1', 'index'),
#  ('sqlite_autoindex_mechanism_refs_2', 'index'),
#  ('sqlite_autoindex_metabolism_1', 'index'),
#  ('sqlite_autoindex_metabolism_2', 'index'),
#  ('sqlite_autoindex_metabolism_refs_1', 'index'),
#  ('sqlite_autoindex_metabolism_refs_2', 'index'),
#  ('sqlite_autoindex_molecule_atc_classification_1', 'index'),
#  ('sqlite_autoindex_molecule_dictionary_1', 'index'),
#  ('sqlite_autoindex_molecule_dictionary_2', 'index'),
#  ('sqlite_autoindex_molecule_frac_classification_1', 'index'),
#  ('sqlite_autoindex_molecule_frac_classification_2', 'index'),
#  ('sqlite_autoindex_molecule_hierarchy_1', 'index'),
#  ('sqlite_autoindex_molecule_hrac_classification_1', 'index'),
#  ('sqlite_autoindex_molecule_hrac_classification_2', 'index'),
#  ('sqlite_autoindex_molecule_irac_classification_1', 'index'),
#  ('sqlite_autoindex_molecule_irac_classification_2', 'index'),
#  ('sqlite_autoindex_molecule_synonyms_1', 'index'),
#  ('sqlite_autoindex_molecule_synonyms_2', 'index'),
#  ('sqlite_autoindex_organism_class_1', 'index'),
#  ('sqlite_autoindex_organism_class_2', 'index'),
#  ('sqlite_autoindex_patent_use_codes_1', 'index'),
#  ('sqlite_autoindex_predicted_binding_domains_1', 'index'),
#  ('sqlite_autoindex_product_patents_1', 'index'),
#  ('sqlite_autoindex_product_patents_2', 'index'),
#  ('sqlite_autoindex_products_1', 'index'),
#  ('sqlite_autoindex_protein_class_synonyms_1', 'index'),
#  ('sqlite_autoindex_protein_class_synonyms_2', 'index'),
#  ('sqlite_autoindex_protein_classification_1', 'index'),
#  ('sqlite_autoindex_relationship_type_1', 'index'),
#  ('sqlite_autoindex_research_companies_1', 'index'),
#  ('sqlite_autoindex_research_companies_2', 'index'),
#  ('sqlite_autoindex_research_stem_1', 'index'),
#  ('sqlite_autoindex_research_stem_2', 'index'),
#  ('sqlite_autoindex_site_components_1', 'index'),
#  ('sqlite_autoindex_site_components_2', 'index'),
#  ('sqlite_autoindex_structural_alert_sets_1', 'index'),
#  ('sqlite_autoindex_structural_alert_sets_2', 'index'),
#  ('sqlite_autoindex_structural_alerts_1', 'index'),
#  ('sqlite_autoindex_structural_alerts_2', 'index'),
#  ('sqlite_autoindex_target_components_1', 'index'),
#  ('sqlite_autoindex_target_components_2', 'index'),
#  ('sqlite_autoindex_target_dictionary_1', 'index'),
#  ('sqlite_autoindex_target_dictionary_2', 'index'),
#  ('sqlite_autoindex_target_relations_1', 'index'),
#  ('sqlite_autoindex_target_type_1', 'index'),
#  ('sqlite_autoindex_tissue_dictionary_1', 'index'),
#  ('sqlite_autoindex_tissue_dictionary_2', 'index'),
#  ('sqlite_autoindex_tissue_dictionary_3', 'index'),
#  ('sqlite_autoindex_tissue_dictionary_4', 'index'),
#  ('sqlite_autoindex_usan_stems_1', 'index'),
#  ('sqlite_autoindex_usan_stems_2', 'index'),
#  ('sqlite_autoindex_variant_sequences_1', 'index'),
#  ('sqlite_autoindex_variant_sequences_2', 'index'),
#  ('sqlite_autoindex_version_1', 'index'),
#  ('sqlite_autoindex_warning_refs_1', 'index'),
#  ('sqlite_stat1', 'table'),
#  ('structural_alert_set_pk', 'index'),
#  ('structural_alert_sets', 'table'),
#  ('structural_alerts', 'table'),
#  ('target_components', 'table'),
#  ('target_dictionary', 'table'),
#  ('target_relations', 'table'),
#  ('target_type', 'table'),
#  ('tissue_dictionary', 'table'),
#  ('tissue_dictionary_pk', 'index'),
#  ('tmp_bao_format', 'index'),
#  ('usan_stems', 'table'),
#  ('variant_sequences', 'table'),
#  ('version', 'table'),
#  ('warning_refs', 'table')]

# %%
doc_ids = ', '.join([f"'{s}'" for s in train_df['Smiles']])
sql = f'''
SELECT m.chembl_id as 'Molecule ChEMBL ID'
     , a.standard_type as 'Standard Type'
     , a.standard_relation as 'Standard Relation'
     , a.standard_value as 'Standard Value'
     , a.standard_units as 'Standard Units'
     , a.pchembl_value as 'pChEMBL Value'
     , aa.chembl_id as 'Assay ChEMBL ID'
     , t.chembl_id as 'Target ChEMBL ID'
     , t.pref_name as 'Target Name'
     , t.organism as 'Target Organism'
     , t.target_type as 'Target Type'
     , d.chembl_id as 'Document ChEMBL ID'
     , a.standard_value as 'IC50_nM'
     , a.pchembl_value as 'pIC50'
     , c.canonical_smiles as 'Smiles'
  FROM compound_structures c
 INNER JOIN molecule_dictionary m ON m.molregno = c.molregno
 INNER JOIN compound_records cr ON cr.molregno = m.molregno
 INNER JOIN activities a ON a.molregno = m.molregno AND a.record_id = cr.record_id AND a.doc_id = cr.doc_id AND a.standard_type = 'IC50' AND a.standard_relation = '=' AND a.standard_units = 'nM'
 INNER JOIN docs d ON d.doc_id = a.doc_id AND d.doc_type IN ('PUBLICATION', 'PATENT')
 INNER JOIN assays aa ON aa.assay_id = a.assay_id AND aa.doc_id = d.doc_id
 INNER JOIN target_dictionary t ON aa.tid = t.tid AND t.target_type = 'SINGLE PROTEIN' AND t.organism = 'Homo sapiens' AND t.chembl_id = 'CHEMBL3778'
 WHERE c.canonical_smiles IN ({doc_ids})
'''
cursor = db.execute(sql)
description = [desc[0] for desc in cursor.description]
df = pd.DataFrame(cursor.fetchall(), columns=description)

# %%
doc_ids = ', '.join([f"'{s}'" for s in test_df['Smiles']])
sql = f'''
SELECT m.chembl_id as 'Molecule ChEMBL ID'
     , a.standard_type as 'Standard Type'
     , a.standard_relation as 'Standard Relation'
     , a.standard_value as 'Standard Value'
     , a.standard_units as 'Standard Units'
     , a.pchembl_value as 'pChEMBL Value'
     , aa.chembl_id as 'Assay ChEMBL ID'
     , t.chembl_id as 'Target ChEMBL ID'
     , t.pref_name as 'Target Name'
     , t.organism as 'Target Organism'
     , t.target_type as 'Target Type'
     , d.chembl_id as 'Document ChEMBL ID'
     , a.standard_value as 'IC50_nM'
     , a.pchembl_value as 'pIC50'
     , c.canonical_smiles as 'Smiles'
  FROM compound_structures c
 INNER JOIN molecule_dictionary m ON m.molregno = c.molregno
 INNER JOIN compound_records cr ON cr.molregno = m.molregno
 INNER JOIN activities a ON a.molregno = m.molregno AND a.record_id = cr.record_id AND a.doc_id = cr.doc_id AND a.standard_type = 'IC50' AND a.standard_relation = '=' AND a.standard_units = 'nM'
 INNER JOIN docs d ON d.doc_id = a.doc_id AND d.doc_type IN ('PUBLICATION', 'PATENT')
 INNER JOIN assays aa ON aa.assay_id = a.assay_id AND aa.doc_id = d.doc_id
 INNER JOIN target_dictionary t ON aa.tid = t.tid AND t.target_type = 'SINGLE PROTEIN' AND t.organism = 'Homo sapiens' AND t.chembl_id = 'CHEMBL3778'
  WHERE c.canonical_smiles IN ({doc_ids})
'''
cursor = db.execute(sql)
description = [desc[0] for desc in cursor.description]
train_df = pd.DataFrame(cursor.fetchall(), columns=description)

# %%
train_df.shape, df.shape
# Out:
# ((2415, 15), (2408, 15))

# %%
sum(train_df['IC50_nM'].isna()), sum(df['pIC50'].isna())
# Out:
# (0, 0)

# %%
test_ddf = pd.read_csv('../data/test.csv')

# %%
test_df.shape, test_ddf.shape
# Out:
# ((0, 15), (113, 2))

# %%
test_df.nunique()
# Out:
# Molecule ChEMBL ID    0
# Standard Type         0
# Standard Relation     0
# Standard Value        0
# Standard Units        0
# pChEMBL Value         0
# Assay ChEMBL ID       0
# Target ChEMBL ID      0
# Target Name           0
# Target Organism       0
# Target Type           0
# Document ChEMBL ID    0
# IC50_nM               0
# pIC50                 0
# Smiles                0
# dtype: int64

# %%
df['src_id'].unique()
# Out:
# array([ 1, 37])

# %%
df['molregno'].value_counts()
# Out:
# molregno
# 2318333    6
# 2519942    6
# 2204519    5
# 1966201    5
# 2329670    5
#           ..
# 2253827    1
# 2248420    1
# 2247143    1
# 2251024    1
# 2797467    1
# Name: count, Length: 1952, dtype: int64

# %%
df[df['molregno'].isin([2318333, 2251024])]
# Out:
#      Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 780       CHEMBL4111673          IC50                 =           17.50
# 1823      CHEMBL4278882          IC50                 =           22.00
# 1824      CHEMBL4278882          IC50                 =          195.00
# 1825      CHEMBL4278882          IC50                 =           22.00
# 1826      CHEMBL4278882          IC50                 =           21.88
# 1827      CHEMBL4278882          IC50                 =          194.98
# 2128      CHEMBL4278882          IC50                 =           36.00
#
#      Standard Units  pChEMBL Value Assay ChEMBL ID Target ChEMBL ID  \
# 780              nM           7.76   CHEMBL3887118       CHEMBL3778
# 1823             nM           7.66   CHEMBL4266468       CHEMBL3778
# 1824             nM           6.71   CHEMBL4266473       CHEMBL3778
# 1825             nM           7.66   CHEMBL4266497       CHEMBL3778
# 1826             nM           7.66   CHEMBL4266468       CHEMBL3778
# 1827             nM           6.71   CHEMBL4266473       CHEMBL3778
# 2128             nM           7.44   CHEMBL4729447       CHEMBL3778
#
#                                      Target Name Target Organism  ... pIC50  \
# 780   Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...  7.76
# 1823  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...  7.66
# 1824  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...  6.71
# 1825  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...  7.66
# 1826  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...  7.66
# 1827  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...  6.71
# 2128  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...  7.44
#
#                                                  Smiles  record_id  molregno  \
# 780   Cn1nccc1Nc1cc(-n2ncc3cc(C#N)cnc32)ncc1C(=O)NC[...    2845578   2251024
# 1823  CC(=O)N1CCN([C@H]2CC[C@H](Nc3ncnn4ccc(C(C)C)c3...    3117294   2318333
# 1824  CC(=O)N1CCN([C@H]2CC[C@H](Nc3ncnn4ccc(C(C)C)c3...    3117294   2318333
# 1825  CC(=O)N1CCN([C@H]2CC[C@H](Nc3ncnn4ccc(C(C)C)c3...    3117294   2318333
# 1826  CC(=O)N1CCN([C@H]2CC[C@H](Nc3ncnn4ccc(C(C)C)c3...    3117294   2318333
# 1827  CC(=O)N1CCN([C@H]2CC[C@H](Nc3ncnn4ccc(C(C)C)c3...    3117294   2318333
# 2128  CC(=O)N1CCN([C@H]2CC[C@H](Nc3ncnn4ccc(C(C)C)c3...    3552672   2318333
#
#       doc_id  compound_key                                      compound_name  \
# 780   102557    BDBM187866                                     US9169252, 409
# 1823  109756            30  trans-1-(4-(4-((5-Isopropylpyrrolo[2,1-f][1,2,...
# 1824  109756            30  trans-1-(4-(4-((5-Isopropylpyrrolo[2,1-f][1,2,...
# 1825  109756            30  trans-1-(4-(4-((5-Isopropylpyrrolo[2,1-f][1,2,...
# 1826  109756            30  trans-1-(4-(4-((5-Isopropylpyrrolo[2,1-f][1,2,...
# 1827  109756            30  trans-1-(4-(4-((5-Isopropylpyrrolo[2,1-f][1,2,...
# 2128  119278             4  1-(4-((trans)-4-(5-isopropylpyrrolo[1,2-f][1,2...
#
#       src_id src_compound_id        cidx
# 780       37            None  BDBM187866
# 1823       1            None     1094813
# 1824       1            None     1094813
# 1825       1            None     1094813
# 1826       1            None     1094813
# 1827       1            None     1094813
# 2128       1            None     1250041
#
# [7 rows x 23 columns]

# %%
train_df[train_df['Molecule ChEMBL ID'] == 'CHEMBL4278882']
# Out:
#      Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 1076      CHEMBL4278882          IC50               '='           21.88
#
#      Standard Units  pChEMBL Value Assay ChEMBL ID Target ChEMBL ID  \
# 1076             nM           7.66   CHEMBL4266468       CHEMBL3778
#
#                                      Target Name Target Organism  \
# 1076  Interleukin-1 receptor-associated kinase 4    Homo sapiens
#
#          Target Type Document ChEMBL ID  IC50_nM  pIC50  \
# 1076  SINGLE PROTEIN      CHEMBL4265877    21.88   7.66
#
#                                                  Smiles
# 1076  CC(=O)N1CCN([C@H]2CC[C@H](Nc3ncnn4ccc(C(C)C)c3...

# %%
df.shape, train_df.shape
# Out:
# ((2408, 15), (1952, 15))

# %%
df.nunique(), train_df.nunique()
# Out:
# (Molecule ChEMBL ID    1952
#  Standard Type            1
#  Standard Relation        1
#  Standard Value         817
#  Standard Units           1
#  pChEMBL Value          389
#  Assay ChEMBL ID        100
#  Target ChEMBL ID         1
#  Target Name              1
#  Target Organism          1
#  Target Type              1
#  Document ChEMBL ID      69
#  IC50_nM                817
#  pIC50                  389
#  Smiles                1952
#  dtype: int64,
#  Molecule ChEMBL ID    1952
#  Standard Type            1
#  Standard Relation        1
#  Standard Value         713
#  Standard Units           1
#  pChEMBL Value          377
#  Assay ChEMBL ID         72
#  Target ChEMBL ID         1
#  Target Name              1
#  Target Organism          1
#  Target Type              1
#  Document ChEMBL ID      66
#  IC50_nM                713
#  pIC50                  377
#  Smiles                1952
#  dtype: int64)

# %%
doc_ids = ', '.join([f"'{s}'" for s in df['Document ChEMBL ID']])
sql = f'''
SELECT d.*
  FROM docs d
 WHERE d.chembl_id IN ({doc_ids})
'''

cursor = db.execute(sql)
description = [desc[0] for desc in cursor.description]
doc_df = pd.DataFrame(cursor.fetchall(), columns=description)

# %%
df.describe()
# Out:
#        Standard Value  pChEMBL Value       IC50_nM        pIC50  \
# count     2408.000000    2408.000000   2408.000000  2408.000000
# mean       665.804917       7.425257    665.804917     7.425257
# std       2552.973831       1.100465   2552.973831     1.100465
# min          0.022000       4.260000      0.022000     4.260000
# 25%          4.875000       6.540000      4.875000     6.540000
# 50%         22.000000       7.660000     22.000000     7.660000
# 75%        286.250000       8.312500    286.250000     8.312500
# max      55000.000000      10.660000  55000.000000    10.660000
#
#               doc_id         year     pubmed_id       src_id  \
# count    2408.000000  2408.000000  1.200000e+03  2408.000000
# mean   102677.378738  2016.193106  2.921698e+07    19.059801
# std     16980.964769     3.020165  4.902917e+06    18.003639
# min     31167.000000  2006.000000  1.656375e+07     1.000000
# 25%    102557.000000  2015.000000  2.628870e+07     1.000000
# 50%    102877.000000  2015.000000  2.917250e+07    37.000000
# 75%    109756.000000  2017.000000  3.309185e+07    37.000000
# max    126114.000000  2023.000000  3.720145e+07    37.000000
#
#        chembl_release_id
# count        2408.000000
# mean           24.406146
# std             6.082619
# min             1.000000
# 25%            24.000000
# 50%            24.000000
# 75%            26.000000
# max            34.000000

# %%
train_df.describe()
# Out:
#        Standard Value  pChEMBL Value       IC50_nM        pIC50
# count     1952.000000    1952.000000   1952.000000  1952.000000
# mean       649.001365       7.518586    649.001365     7.518586
# std       2639.946734       1.107959   2639.946734     1.107959
# min          0.022000       4.260000      0.022000     4.260000
# 25%          4.100000       6.680000      4.100000     6.680000
# 50%         15.250000       7.820000     15.250000     7.820000
# 75%        209.197500       8.390000    209.197500     8.390000
# max      55000.000000      10.660000  55000.000000    10.660000

# %%
standard_value_diff = set(df['pChEMBL Value'].unique()) - set(train_df['pChEMBL Value'].unique())
print(len(standard_value_diff))
ddf = df[df['pChEMBL Value'].isin(standard_value_diff)]
# Out:
# 12

# %%
df['patent_id'].isna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2403    True
# 2404    True
# 2405    True
# 2406    True
# 2407    True
# Name: patent_id, Length: 2408, dtype: bool

# %%
ddf[ddf['journal'].isna() == False]
# Out:
#      Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 311       CHEMBL3622518          IC50                 =         1900.00
# 1615      CHEMBL4075552          IC50                 =          115.00
# 1618      CHEMBL4071526          IC50                 =           29.50
# 1664      CHEMBL4105582          IC50                 =        23000.00
# 1812      CHEMBL4283453          IC50                 =         2340.00
# 1814      CHEMBL4283453          IC50                 =         2344.23
# 1834      CHEMBL4282348          IC50                 =         1650.00
# 1836      CHEMBL4282348          IC50                 =         1659.59
# 1839      CHEMBL4293607          IC50                 =           21.38
# 2068      CHEMBL4783351          IC50                 =         1375.00
# 2362      CHEMBL5283237          IC50                 =        21000.00
# 2364      CHEMBL5270577          IC50                 =         6800.00
#
#      Standard Units  pChEMBL Value Assay ChEMBL ID Target ChEMBL ID  \
# 311              nM           5.72   CHEMBL3625606       CHEMBL3778
# 1615             nM           6.94   CHEMBL4015947       CHEMBL3778
# 1618             nM           7.53   CHEMBL4015947       CHEMBL3778
# 1664             nM           4.64   CHEMBL4026983       CHEMBL3778
# 1812             nM           5.63   CHEMBL4266473       CHEMBL3778
# 1814             nM           5.63   CHEMBL4266473       CHEMBL3778
# 1834             nM           5.78   CHEMBL4266473       CHEMBL3778
# 1836             nM           5.78   CHEMBL4266473       CHEMBL3778
# 1839             nM           7.67   CHEMBL4266468       CHEMBL3778
# 2068             nM           5.86   CHEMBL4673036       CHEMBL3778
# 2362             nM           4.68   CHEMBL5246638       CHEMBL3778
# 2364             nM           5.17   CHEMBL5246638       CHEMBL3778
#
#                                      Target Name Target Organism  ...  \
# 311   Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1615  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1618  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1664  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1812  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1814  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1834  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1836  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 1839  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 2068  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 2362  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
# 2364  Interleukin-1 receptor-associated kinase 4    Homo sapiens  ...
#
#           chembl_id                                              title  \
# 311   CHEMBL3621203  Discovery and Structure Enabled Synthesis of 2...
# 1615  CHEMBL4014327  Discovery of Clinical Candidate 1-{[(2S,3S,4S)...
# 1618  CHEMBL4014327  Discovery of Clinical Candidate 1-{[(2S,3S,4S)...
# 1664  CHEMBL4024763  Discovery and Optimization of Pyrrolopyrimidin...
# 1812  CHEMBL4265877  Optimization of permeability in a series of py...
# 1814  CHEMBL4265877  Optimization of permeability in a series of py...
# 1834  CHEMBL4265877  Optimization of permeability in a series of py...
# 1836  CHEMBL4265877  Optimization of permeability in a series of py...
# 1839  CHEMBL4265877  Optimization of permeability in a series of py...
# 2068  CHEMBL4665913  Discovery of CA-4948, an Orally Bioavailable I...
# 2362  CHEMBL5244269  Improving metabolic stability and removing ald...
# 2364  CHEMBL5244269  Improving metabolic stability and removing ald...
#
#          doc_type                                            authors  \
# 311   PUBLICATION  Seganish WM, Fischmann TO, Sherborne B, Matasi...
# 1615  PUBLICATION  Lee KL, Ambler CM, Anderson DR, Boscoe BP, Bre...
# 1618  PUBLICATION  Lee KL, Ambler CM, Anderson DR, Boscoe BP, Bre...
# 1664  PUBLICATION  Scott JS, Degorce SL, Anjum R, Culshaw J, Davi...
# 1812  PUBLICATION  Degorce SL, Anjum R, Dillman KS, Drew L, Groom...
# 1814  PUBLICATION  Degorce SL, Anjum R, Dillman KS, Drew L, Groom...
# 1834  PUBLICATION  Degorce SL, Anjum R, Dillman KS, Drew L, Groom...
# 1836  PUBLICATION  Degorce SL, Anjum R, Dillman KS, Drew L, Groom...
# 1839  PUBLICATION  Degorce SL, Anjum R, Dillman KS, Drew L, Groom...
# 2068  PUBLICATION  Gummadi VR,Boruah A,Ainan BR,Vare BR,Manda S,G...
# 2362  PUBLICATION  Degorce SL, Aagaard A, Anjum R, Cumming IA, Di...
# 2364  PUBLICATION  Degorce SL, Aagaard A, Anjum R, Cumming IA, Di...
#
#                                                abstract  patent_id      ridx  \
# 311   We report the identification and synthesis of ...       None      CLD0
# 1615  Through fragment-based drug design focused on ...       None  28498658
# 1618  Through fragment-based drug design focused on ...       None  28498658
# 1664  Herein we report the optimization of a series ...       None  29172502
# 1812  We have developed a series of orally efficacio...       None  29398441
# 1814  We have developed a series of orally efficacio...       None  29398441
# 1834  We have developed a series of orally efficacio...       None  29398441
# 1836  We have developed a series of orally efficacio...       None  29398441
# 1839  We have developed a series of orally efficacio...       None  29398441
# 2068  Small molecule potent IRAK4 inhibitors from a ...       None  33335659
# 2362  In this article, we report our efforts towards...       None  33091850
# 2364  In this article, we report our efforts towards...       None  33091850
#
#       src_id chembl_release_id contact
# 311        1                22    None
# 1615       1                25    None
# 1618       1                25    None
# 1664       1                25    None
# 1812       1                26    None
# 1814       1                26    None
# 1834       1                26    None
# 1836       1                26    None
# 1839       1                26    None
# 2068       1                30    None
# 2362       1                34    None
# 2364       1                34    None
#
# [12 rows x 34 columns]

# %%
doc_df.nunique()
# Out:
# doc_id               69
# journal               6
# year                 17
# volume               31
# issue                27
# first_page           64
# last_page            64
# pubmed_id            64
# doi                  64
# chembl_id            69
# title                69
# doc_type              2
# authors              62
# abstract             63
# patent_id             5
# ridx                 43
# src_id                2
# chembl_release_id    19
# contact               0
# dtype: int64

# %%
assay_ids = ', '.join([f"'{s}'" for s in df['Assay ChEMBL ID']])
sql = f'''
SELECT d.*
  FROM assays d
 WHERE d.chembl_id IN ({assay_ids})
'''

cursor = db.execute(sql)
description = [desc[0] for desc in cursor.description]
assay_df = pd.DataFrame(cursor.fetchall(), columns=description)

assay_ids = ', '.join([f"'{s}'" for s in train_df['Assay ChEMBL ID']])
cursor = db.execute(sql)
description = [desc[0] for desc in cursor.description]
assay_train_df = pd.DataFrame(cursor.fetchall(), columns=description)

# %%
assay_df.nunique(), assay_train_df.nunique()
# Out:
# (assay_id                      100
#  doc_id                         69
#  description                    74
#  assay_type                      1
#  assay_test_type                 0
#  assay_category                  0
#  assay_organism                  1
#  assay_tax_id                    1
#  assay_strain                    0
#  assay_tissue                    1
#  assay_cell_type                 6
#  assay_subcellular_fraction      0
#  tid                             1
#  relationship_type               2
#  confidence_score                2
#  curated_by                      3
#  src_id                          2
#  src_assay_id                   34
#  chembl_id                     100
#  cell_id                         3
#  bao_format                      4
#  tissue_id                       1
#  variant_id                      0
#  aidx                           64
#  dtype: int64,
#  assay_id                      100
#  doc_id                         69
#  description                    74
#  assay_type                      1
#  assay_test_type                 0
#  assay_category                  0
#  assay_organism                  1
#  assay_tax_id                    1
#  assay_strain                    0
#  assay_tissue                    1
#  assay_cell_type                 6
#  assay_subcellular_fraction      0
#  tid                             1
#  relationship_type               2
#  confidence_score                2
#  curated_by                      3
#  src_id                          2
#  src_assay_id                   34
#  chembl_id                     100
#  cell_id                         3
#  bao_format                      4
#  tissue_id                       1
#  variant_id                      0
#  aidx                           64
#  dtype: int64)

# %%
doc_ids = ', '.join([f"'{s}'" for s in train_df['Document ChEMBL ID']])
sql = f'''
SELECT d.*
  FROM docs d
 WHERE d.chembl_id IN ({doc_ids})
'''

cursor = db.execute(sql)
description = [desc[0] for desc in cursor.description]
doc_train_df = pd.DataFrame(cursor.fetchall(), columns=description)

# %%
doc_train_df.nunique()
# Out:
# doc_id               66
# journal               6
# year                 17
# volume               29
# issue                27
# first_page           61
# last_page            61
# pubmed_id            61
# doi                  61
# chembl_id            66
# title                66
# doc_type              2
# authors              59
# abstract             60
# patent_id             5
# ridx                 41
# src_id                2
# chembl_release_id    19
# contact               0
# dtype: int64

# %%
set(doc_df['doc_id'].unique()) - set(doc_train_df['doc_id'].unique())
# Out:
# {np.int64(47102), np.int64(107047), np.int64(119003)}

# %%
doc_df[doc_df['doc_id'].isin([47102, 107047, 119003])]
# Out:
#     doc_id          journal  year volume issue first_page last_page  \
# 0    47102       J Med Chem  2009     52    10       3191      3204
# 37  107047   Eur J Med Chem  2017    141  None        657       675
# 52  119003  Bioorg Med Chem  2018     26   8.0       1740      1750
#
#      pubmed_id                           doi      chembl_id  \
# 0   19397322.0             10.1021/jm800861c  CHEMBL1138507
# 37  29107425.0  10.1016/j.ejmech.2017.10.003  CHEMBL4145442
# 52  29523467.0     10.1016/j.bmc.2018.02.022  CHEMBL4715818
#
#                                                 title     doc_type  \
# 0   Synthesis, activity, and pharmacophore develop...  PUBLICATION
# 37  Novel LCK/FMS inhibitors based on phenoxypyrim...  PUBLICATION
# 52  Novel quinazoline derivatives bearing various ...  PUBLICATION
#
#                                               authors  \
# 0   Hall MD, Salam NK, Hellawell JL, Fales HM, Ken...
# 37  Farag AK, Elkamhawy A, Londhe AM, Lee KT, Pae ...
# 52               Hou W,Ren Y,Zhang Z,Sun H,Ma Y,Yan B
#
#                                              abstract patent_id      ridx  \
# 0   We have recently identified a new class of com...      None      CLD0
# 37  Tyrosine kinases including LCK and FMS are inv...      None  29107425
# 52  A series of novel quinazoline derivatives bear...      None  29523467
#
#     src_id  chembl_release_id contact
# 0        1                  2    None
# 37       1                 26    None
# 52       1                 30    None

# %%
doc_df[doc_df['doc_id'].isin([47102, 107047, 119003]) == False]
# Out:
#     doc_id               journal  year volume issue first_page last_page  \
# 1    38711  Bioorg Med Chem Lett  2008     18    11       3211      3214
# 2    39491  Bioorg Med Chem Lett  2008     18    12       3656      3660
# 3    31167  Bioorg Med Chem Lett  2006     16    11       2842      2845
# 4    42165  Bioorg Med Chem Lett  2008     18    11       3291      3295
# 5    52613              Leukemia  2009     23     3        477       485
# ..     ...                   ...   ...    ...   ...        ...       ...
# 64  124270            J Med Chem  2021     64   3.0       1283      1345
# 65  124282            J Med Chem  2021     64   6.0       2878      2900
# 66  125655       Bioorg Med Chem  2020     28  23.0     115815    115815
# 67  126082       Bioorg Med Chem  2023     87  None     117302    117302
# 68  126114        Eur J Med Chem  2017    142  None        328       375
#
#      pubmed_id                           doi      chembl_id  \
# 1   18474425.0    10.1016/j.bmcl.2008.04.058  CHEMBL1143094
# 2   18501603.0    10.1016/j.bmcl.2008.04.042  CHEMBL1145577
# 3   16563752.0    10.1016/j.bmcl.2006.03.020  CHEMBL1147720
# 4   18482836.0    10.1016/j.bmcl.2008.04.039  CHEMBL1150395
# 5   19039322.0          10.1038/leu.2008.334  CHEMBL1240341
# ..         ...                           ...            ...
# 64  33481605.0  10.1021/acs.jmedchem.0c01511  CHEMBL5149965
# 65  33719439.0  10.1021/acs.jmedchem.0c01851  CHEMBL5149977
# 66  33091850.0     10.1016/j.bmc.2020.115815  CHEMBL5244269
# 67  37201454.0     10.1016/j.bmc.2023.117302  CHEMBL5257151
# 68  28851503.0  10.1016/j.ejmech.2017.08.009  CHEMBL5260813
#
#                                                 title     doc_type  \
# 1      IRAK-4 inhibitors. Part 1: a series of amides.  PUBLICATION
# 2   IRAK-4 inhibitors. Part III: a series of imida...  PUBLICATION
# 3   Discovery and initial SAR of inhibitors of int...  PUBLICATION
# 4   IRAK-4 inhibitors. Part II: a structure-based ...  PUBLICATION
# 5   Global target profile of the kinase inhibitor ...  PUBLICATION
# ..                                                ...          ...
# 64  Small-Molecule Kinase Inhibitors for the Treat...  PUBLICATION
# 65  FLT3 Inhibitors in Acute Myeloid Leukemia: Cha...  PUBLICATION
# 66  Improving metabolic stability and removing ald...  PUBLICATION
# 67  Design, synthesis, and pharmacological evaluat...  PUBLICATION
# 68  An overview on the recent developments of 1,2,...  PUBLICATION
#
#                                               authors  \
# 1   Buckley GM, Gowers L, Higueruelo AP, Jenkins K...
# 2   Buckley GM, Fosbeary R, Fraser JL, Gowers L, H...
# 3   Powers JP, Li S, Jaen JC, Liu J, Walker NP, Wa...
# 4   Buckley GM, Ceska TA, Fraser JL, Gowers L, Gro...
# 5   Remsing Rix LL, Rix U, Colinge J, Hantschel O,...
# ..                                                ...
# 64              Xie Z, Yang X, Duan Y, Han J, Liao C.
# 65  Wang Z, Cai J, Cheng J, Yang W, Zhu Y, Li H, L...
# 66  Degorce SL, Aagaard A, Anjum R, Cumming IA, Di...
# 67  Inami H, Mizutani T, Watanabe J, Hayashida H, ...
# 68  Cascioferro S, Parrino B, Spanò V, Carbone A, ...
#
#                                              abstract patent_id      ridx  \
# 1   The synthesis and profile of a series of amide...      None      CLD0
# 2   Following the identification of a potent IRAK ...      None      CLD0
# 3   High-throughput screening of a small-molecule ...      None      CLD0
# 4   A potent IRAK-4 inhibitor was identified throu...      None      CLD0
# 5   The detailed molecular mechanism of action of ...      None      CLD0
# ..                                                ...       ...       ...
# 64  Great successes have been achieved in developi...      None  33481605
# 65  Mutations in the FMS-like tyrosine kinase 3 (<...      None  33719439
# 66  In this article, we report our efforts towards...      None  33091850
# 67  Interleukin-1 receptor-associated kinase 4 (IR...      None  37201454
# 68  The synthesis, the antitumor activity, the SAR...      None  28851503
#
#     src_id  chembl_release_id contact
# 1        1                  1    None
# 2        1                  1    None
# 3        1                  1    None
# 4        1                  2    None
# 5        1                 10    None
# ..     ...                ...     ...
# 64       1                 33    None
# 65       1                 33    None
# 66       1                 34    None
# 67       1                 34    None
# 68       1                 34    None
#
# [66 rows x 19 columns]

# %%
doc_df[doc_df['contact'].isna()]
# Out:
#     doc_id               journal  year volume issue first_page last_page  \
# 0    47102            J Med Chem  2009     52    10       3191      3204
# 1    38711  Bioorg Med Chem Lett  2008     18    11       3211      3214
# 2    39491  Bioorg Med Chem Lett  2008     18    12       3656      3660
# 3    31167  Bioorg Med Chem Lett  2006     16    11       2842      2845
# 4    42165  Bioorg Med Chem Lett  2008     18    11       3291      3295
# ..     ...                   ...   ...    ...   ...        ...       ...
# 64  124270            J Med Chem  2021     64   3.0       1283      1345
# 65  124282            J Med Chem  2021     64   6.0       2878      2900
# 66  125655       Bioorg Med Chem  2020     28  23.0     115815    115815
# 67  126082       Bioorg Med Chem  2023     87  None     117302    117302
# 68  126114        Eur J Med Chem  2017    142  None        328       375
#
#      pubmed_id                           doi      chembl_id  \
# 0   19397322.0             10.1021/jm800861c  CHEMBL1138507
# 1   18474425.0    10.1016/j.bmcl.2008.04.058  CHEMBL1143094
# 2   18501603.0    10.1016/j.bmcl.2008.04.042  CHEMBL1145577
# 3   16563752.0    10.1016/j.bmcl.2006.03.020  CHEMBL1147720
# 4   18482836.0    10.1016/j.bmcl.2008.04.039  CHEMBL1150395
# ..         ...                           ...            ...
# 64  33481605.0  10.1021/acs.jmedchem.0c01511  CHEMBL5149965
# 65  33719439.0  10.1021/acs.jmedchem.0c01851  CHEMBL5149977
# 66  33091850.0     10.1016/j.bmc.2020.115815  CHEMBL5244269
# 67  37201454.0     10.1016/j.bmc.2023.117302  CHEMBL5257151
# 68  28851503.0  10.1016/j.ejmech.2017.08.009  CHEMBL5260813
#
#                                                 title     doc_type  \
# 0   Synthesis, activity, and pharmacophore develop...  PUBLICATION
# 1      IRAK-4 inhibitors. Part 1: a series of amides.  PUBLICATION
# 2   IRAK-4 inhibitors. Part III: a series of imida...  PUBLICATION
# 3   Discovery and initial SAR of inhibitors of int...  PUBLICATION
# 4   IRAK-4 inhibitors. Part II: a structure-based ...  PUBLICATION
# ..                                                ...          ...
# 64  Small-Molecule Kinase Inhibitors for the Treat...  PUBLICATION
# 65  FLT3 Inhibitors in Acute Myeloid Leukemia: Cha...  PUBLICATION
# 66  Improving metabolic stability and removing ald...  PUBLICATION
# 67  Design, synthesis, and pharmacological evaluat...  PUBLICATION
# 68  An overview on the recent developments of 1,2,...  PUBLICATION
#
#                                               authors  \
# 0   Hall MD, Salam NK, Hellawell JL, Fales HM, Ken...
# 1   Buckley GM, Gowers L, Higueruelo AP, Jenkins K...
# 2   Buckley GM, Fosbeary R, Fraser JL, Gowers L, H...
# 3   Powers JP, Li S, Jaen JC, Liu J, Walker NP, Wa...
# 4   Buckley GM, Ceska TA, Fraser JL, Gowers L, Gro...
# ..                                                ...
# 64              Xie Z, Yang X, Duan Y, Han J, Liao C.
# 65  Wang Z, Cai J, Cheng J, Yang W, Zhu Y, Li H, L...
# 66  Degorce SL, Aagaard A, Anjum R, Cumming IA, Di...
# 67  Inami H, Mizutani T, Watanabe J, Hayashida H, ...
# 68  Cascioferro S, Parrino B, Spanò V, Carbone A, ...
#
#                                              abstract patent_id      ridx  \
# 0   We have recently identified a new class of com...      None      CLD0
# 1   The synthesis and profile of a series of amide...      None      CLD0
# 2   Following the identification of a potent IRAK ...      None      CLD0
# 3   High-throughput screening of a small-molecule ...      None      CLD0
# 4   A potent IRAK-4 inhibitor was identified throu...      None      CLD0
# ..                                                ...       ...       ...
# 64  Great successes have been achieved in developi...      None  33481605
# 65  Mutations in the FMS-like tyrosine kinase 3 (<...      None  33719439
# 66  In this article, we report our efforts towards...      None  33091850
# 67  Interleukin-1 receptor-associated kinase 4 (IR...      None  37201454
# 68  The synthesis, the antitumor activity, the SAR...      None  28851503
#
#     src_id  chembl_release_id contact
# 0        1                  2    None
# 1        1                  1    None
# 2        1                  1    None
# 3        1                  1    None
# 4        1                  2    None
# ..     ...                ...     ...
# 64       1                 33    None
# 65       1                 33    None
# 66       1                 34    None
# 67       1                 34    None
# 68       1                 34    None
#
# [69 rows x 19 columns]

# %%
doc_train_df[doc_train_df['contact'].isna()]
# Out:
#     doc_id               journal  year volume issue first_page last_page  \
# 0    38711  Bioorg Med Chem Lett  2008     18    11       3211      3214
# 1    39491  Bioorg Med Chem Lett  2008     18    12       3656      3660
# 2    31167  Bioorg Med Chem Lett  2006     16    11       2842      2845
# 3    42165  Bioorg Med Chem Lett  2008     18    11       3291      3295
# 4    52613              Leukemia  2009     23     3        477       485
# ..     ...                   ...   ...    ...   ...        ...       ...
# 61  124270            J Med Chem  2021     64   3.0       1283      1345
# 62  124282            J Med Chem  2021     64   6.0       2878      2900
# 63  125655       Bioorg Med Chem  2020     28  23.0     115815    115815
# 64  126082       Bioorg Med Chem  2023     87  None     117302    117302
# 65  126114        Eur J Med Chem  2017    142  None        328       375
#
#      pubmed_id                           doi      chembl_id  \
# 0   18474425.0    10.1016/j.bmcl.2008.04.058  CHEMBL1143094
# 1   18501603.0    10.1016/j.bmcl.2008.04.042  CHEMBL1145577
# 2   16563752.0    10.1016/j.bmcl.2006.03.020  CHEMBL1147720
# 3   18482836.0    10.1016/j.bmcl.2008.04.039  CHEMBL1150395
# 4   19039322.0          10.1038/leu.2008.334  CHEMBL1240341
# ..         ...                           ...            ...
# 61  33481605.0  10.1021/acs.jmedchem.0c01511  CHEMBL5149965
# 62  33719439.0  10.1021/acs.jmedchem.0c01851  CHEMBL5149977
# 63  33091850.0     10.1016/j.bmc.2020.115815  CHEMBL5244269
# 64  37201454.0     10.1016/j.bmc.2023.117302  CHEMBL5257151
# 65  28851503.0  10.1016/j.ejmech.2017.08.009  CHEMBL5260813
#
#                                                 title     doc_type  \
# 0      IRAK-4 inhibitors. Part 1: a series of amides.  PUBLICATION
# 1   IRAK-4 inhibitors. Part III: a series of imida...  PUBLICATION
# 2   Discovery and initial SAR of inhibitors of int...  PUBLICATION
# 3   IRAK-4 inhibitors. Part II: a structure-based ...  PUBLICATION
# 4   Global target profile of the kinase inhibitor ...  PUBLICATION
# ..                                                ...          ...
# 61  Small-Molecule Kinase Inhibitors for the Treat...  PUBLICATION
# 62  FLT3 Inhibitors in Acute Myeloid Leukemia: Cha...  PUBLICATION
# 63  Improving metabolic stability and removing ald...  PUBLICATION
# 64  Design, synthesis, and pharmacological evaluat...  PUBLICATION
# 65  An overview on the recent developments of 1,2,...  PUBLICATION
#
#                                               authors  \
# 0   Buckley GM, Gowers L, Higueruelo AP, Jenkins K...
# 1   Buckley GM, Fosbeary R, Fraser JL, Gowers L, H...
# 2   Powers JP, Li S, Jaen JC, Liu J, Walker NP, Wa...
# 3   Buckley GM, Ceska TA, Fraser JL, Gowers L, Gro...
# 4   Remsing Rix LL, Rix U, Colinge J, Hantschel O,...
# ..                                                ...
# 61              Xie Z, Yang X, Duan Y, Han J, Liao C.
# 62  Wang Z, Cai J, Cheng J, Yang W, Zhu Y, Li H, L...
# 63  Degorce SL, Aagaard A, Anjum R, Cumming IA, Di...
# 64  Inami H, Mizutani T, Watanabe J, Hayashida H, ...
# 65  Cascioferro S, Parrino B, Spanò V, Carbone A, ...
#
#                                              abstract patent_id      ridx  \
# 0   The synthesis and profile of a series of amide...      None      CLD0
# 1   Following the identification of a potent IRAK ...      None      CLD0
# 2   High-throughput screening of a small-molecule ...      None      CLD0
# 3   A potent IRAK-4 inhibitor was identified throu...      None      CLD0
# 4   The detailed molecular mechanism of action of ...      None      CLD0
# ..                                                ...       ...       ...
# 61  Great successes have been achieved in developi...      None  33481605
# 62  Mutations in the FMS-like tyrosine kinase 3 (<...      None  33719439
# 63  In this article, we report our efforts towards...      None  33091850
# 64  Interleukin-1 receptor-associated kinase 4 (IR...      None  37201454
# 65  The synthesis, the antitumor activity, the SAR...      None  28851503
#
#     src_id  chembl_release_id contact
# 0        1                  1    None
# 1        1                  1    None
# 2        1                  1    None
# 3        1                  2    None
# 4        1                 10    None
# ..     ...                ...     ...
# 61       1                 33    None
# 62       1                 33    None
# 63       1                 34    None
# 64       1                 34    None
# 65       1                 34    None
#
# [66 rows x 19 columns]

# %%
df.nunique()
# Out:
# Molecule ChEMBL ID    1952
# Standard Type            1
# Standard Relation        1
# Standard Value         817
# Standard Units           1
# pChEMBL Value          389
# Assay ChEMBL ID        100
# Target ChEMBL ID         1
# Target Name              1
# Target Organism          1
# Target Type              1
# Document ChEMBL ID      69
# IC50_nM                817
# pIC50                  389
# Smiles                1952
# doc_id                  69
# journal                  6
# year                    17
# volume                  31
# issue                   27
# first_page              64
# last_page               64
# pubmed_id               64
# doi                     64
# chembl_id               69
# title                   69
# doc_type                 2
# authors                 62
# abstract                63
# patent_id                5
# ridx                    43
# src_id                   2
# chembl_release_id       19
# contact                  0
# dtype: int64

# %%
train_df.nunique()
# Out:
# Molecule ChEMBL ID    1952
# Standard Type            1
# Standard Relation        1
# Standard Value         713
# Standard Units           1
# pChEMBL Value          377
# Assay ChEMBL ID         72
# Target ChEMBL ID         1
# Target Name              1
# Target Organism          1
# Target Type              1
# Document ChEMBL ID      66
# IC50_nM                713
# pIC50                  377
# Smiles                1952
# dtype: int64

# %%
train_df['Target ChEMBL ID']
# Out:
# 0       CHEMBL3778
# 1       CHEMBL3778
# 2       CHEMBL3778
# 3       CHEMBL3778
# 4       CHEMBL3778
#            ...
# 1947    CHEMBL3778
# 1948    CHEMBL3778
# 1949    CHEMBL3778
# 1950    CHEMBL3778
# 1951    CHEMBL3778
# Name: Target ChEMBL ID, Length: 1952, dtype: object

# %%
while True:
    sql = input()
    if sql == 'd':
        break
    cursor = db.execute(sql)
    df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])
    print(df)
    cursor.close()

# %% [markdown]
# ---
# # test.csv 의 smiles는 chembl에 등록되지 않은 대상
# - 따라서 train set에서 얻을 수 있는 feature 정보들을 직접 활용이 불가함
# - 우회할 수 있는 방법으로, 각 test smiles와 임계 유사도 이상을 갖는 molecule를 기준으로 train 과 동일한 feature들을 추출해 통계값을 test smiles의 feature로 대체하고자 함

# %%
# ChEBML API 로 임계 유사도 이상 molecule 정보 조회하기
import requests
import xml.etree.ElementTree as ET

# SMILES 문자열
test_df = pd.read_csv('../data/test.csv')
similarity_threshold = 50  # 유사도 임계값 (0-100 사이)
output_df = {}
for smiles in test_df['Smiles']: # 예시로 Ethanol 사용
    # ChEMBL API URL
    url = f"https://www.ebi.ac.uk/chembl/api/data/similarity/{smiles}/{similarity_threshold}"

    # 요청 보내기
    response = requests.get(url)

    # 결과 확인
    if response.status_code == 200:
        # XML 파싱
        root = ET.fromstring(response.text)

        # molecule_chembl_id 추출
        chembl_ids = [elem.text for elem in root.findall(".//molecule_chembl_id")]

        chembl_ids = ', '.join([f"'{s}'" for s in chembl_ids])

        print(chembl_ids)

        sql = f'''
        SELECT m.chembl_id as 'Molecule ChEMBL ID'
            , a.standard_type as 'Standard Type'
            , a.standard_relation as 'Standard Relation'
            , a.standard_value as 'Standard Value'
            , a.standard_units as 'Standard Units'
            , a.pchembl_value as 'pChEMBL Value'
            , aa.chembl_id as 'Assay ChEMBL ID'
            , t.chembl_id as 'Target ChEMBL ID'
            , t.pref_name as 'Target Name'
            , t.organism as 'Target Organism'
            , t.target_type as 'Target Type'
            , d.chembl_id as 'Document ChEMBL ID'
            , a.standard_value as 'IC50_nM'
            , a.pchembl_value as 'pIC50'
            , c.canonical_smiles as 'Smiles'
        FROM compound_structures c
        INNER JOIN molecule_dictionary m ON m.molregno = c.molregno
        INNER JOIN compound_records cr ON cr.molregno = m.molregno
        INNER JOIN activities a ON a.molregno = m.molregno AND a.record_id = cr.record_id AND a.doc_id = cr.doc_id AND a.standard_type = 'IC50' AND a.standard_relation = '=' AND a.standard_units = 'nM'
        INNER JOIN docs d ON d.doc_id = a.doc_id AND d.doc_type IN ('PUBLICATION', 'PATENT')
        INNER JOIN assays aa ON aa.assay_id = a.assay_id AND aa.doc_id = d.doc_id
        INNER JOIN target_dictionary t ON aa.tid = t.tid AND t.target_type = 'SINGLE PROTEIN' AND t.organism = 'Homo sapiens' AND t.chembl_id = 'CHEMBL3778'
        WHERE m.chembl_id IN ({chembl_ids})
        '''
        cursor = db.execute(sql)
        description = [desc[0] for desc in cursor.description]
        test = pd.DataFrame(cursor.fetchall(), columns=description)

        output_df[smiles] = test
    else:
        print(f"Error: {response.status_code}")


output_df = pd.DataFrame(index=output_df.keys(), data=output_df.values())
# Out:
# 'CHEMBL257127', 'CHEMBL257127', 'CHEMBL254546', 'CHEMBL254546', 'CHEMBL404514', 'CHEMBL404514', 'CHEMBL403662', 'CHEMBL403662', 'CHEMBL259797', 'CHEMBL259797', 'CHEMBL407821', 'CHEMBL407821', 'CHEMBL3354514', 'CHEMBL3354514'
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
#
# 'CHEMBL3676302', 'CHEMBL3676302', 'CHEMBL3676304', 'CHEMBL3676304', 'CHEMBL3676303', 'CHEMBL3676303', 'CHEMBL3676258', 'CHEMBL3676258', 'CHEMBL3676268', 'CHEMBL3676268'
#
#
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
#
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
#
#
#
# Error: 404
#
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
#
# Error: 404
# Error: 404
# Error: 404
#
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# 'CHEMBL254546', 'CHEMBL254546', 'CHEMBL257127', 'CHEMBL257127', 'CHEMBL2037108', 'CHEMBL2037108'
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
# Error: 404
#
# Error: 404
#
# Error: 404
# Error: 404
#
# Error: 404
# 'CHEMBL2037107', 'CHEMBL2037107'
# Error: 404
#
#
# Error: 404
# Error: 404
# Error: 404
# 'CHEMBL2037108', 'CHEMBL2037108'
# Error: 404
# Error: 404
#
# Error: 404
# Error: 404
# Error: 404
#
# Error: 404
# Error: 404
# Error: 404
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[236], line 62
#      58     else:
#      59         print(f"Error: {response.status_code}")
# ---> 62 output_df = pd.DataFrame(index=output_df.keys(), data=output_df.values())
#
# File ~/Library/Caches/pypoetry/virtualenvs/ic50-prediction-aM1espru-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)
#     864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
#    (...)
#     881         typ=manager,
#     882     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/ic50-prediction-aM1espru-py3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:319, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
# --> 319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     321 if dtype is not None and values.dtype != dtype:
#     322     # GH#40110 see similar check inside sanitize_array
#     323     values = sanitize_array(
#     324         values,
#     325         None,
#    (...)
#     328         allow_2d=True,
#     329     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/ic50-prediction-aM1espru-py3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:575, in _prep_ndarraylike(values, copy)
#     569 # we could have a 1-dim or 2-dim list here
#     570 # this is equiv of np.asarray, but does object conversion
#     571 # and platform dtype preservation
#     572 # does not convert e.g. [1, "a", True] to ["1", "a", "True"] like
#     573 #  np.asarray would
#     574 if is_list_like(values[0]):
# --> 575     values = np.array([convert(v) for v in values])
#     576 elif isinstance(values[0], np.ndarray) and values[0].ndim == 0:
#     577     # GH#21861 see test_constructor_list_of_lists
#     578     values = np.array([convert(v) for v in values])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (22,) + inhomogeneous part.
